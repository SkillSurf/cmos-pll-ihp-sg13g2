# %%
import matplotlib.pyplot as plt

# Data from your table
vctl = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2]
fnew = [0.0228, 0.132, 0.39, 0.708, 1.077, 1.316, 1.42, 1.5, 1.46]
fold = [0.00296, 0.021, 0.025, 0.076, 0.207, 0.465, 0.86, 1.44, 2.1]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(vctl, fnew, marker='o', label='fnew', color='blue')
plt.plot(vctl, fold, marker='s', label='fold', color='red')
plt.xlabel('Vctl (V)')
plt.ylabel('Frequency (GHz)')
plt.title('Vctl vs Frequency')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
